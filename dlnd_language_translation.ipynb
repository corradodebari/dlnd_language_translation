# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_word_ids =  [[source_vocab_to_int[word] for word in line.split()] for line in source_text.split('\n')]
    target_word_ids = [[target_vocab_to_int[word] for word in line.split()] + [target_vocab_to_int['<EOS>']] for line in target_text.split('\n')]
    print(source_text)
    print(source_word_ids)
    print(target_text)
    print(target_word_ids)
    print("EOS",target_vocab_to_int['<EOS>'])
    print(source_text)
    return source_word_ids, target_word_ids

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# [[27, 25, 14, 29, 6, 15, 12, 17, 24, 7, 14, 8, 21, 32, 10], [11, 5, 16, 14, 22, 23, 15, 18, 17, 24, 7, 14, 22, 28, 21, 26, 10], [20, 14, 22, 6, 15, 9, 17, 24, 7, 14, 22, 19, 21, 13, 10], [11, 5, 16, 14, 29, 30, 15, 13, 17, 24, 7, 14, 4, 21, 31, 10]]
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# [[30, 27, 32, 16, 33, 17, 6, 26, 15, 14, 22, 32, 9, 5, 8, 11, 1], [25, 20, 32, 31, 18, 5, 12, 15, 14, 22, 13, 10, 5, 24, 11, 1], [19, 32, 31, 33, 5, 21, 15, 14, 22, 32, 31, 28, 5, 7, 11, 1], [25, 20, 32, 16, 23, 5, 7, 15, 14, 22, 4, 18, 5, 29, 11, 1]]
# EOS 1
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# C:\Users\cdebari\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input_data = tf.placeholder(tf.int32, [None, None], name='input')
    targets =  tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate =  tf.placeholder(tf.float32, name='learning_rate')
    keep_probability =  tf.placeholder(tf.float32, name='keep_prob')
    target_sequence_length =  target_sequence_length = tf.placeholder(tf.int32, (None,), name='target_sequence_length')
    max_target_sequence_length =  tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length =  tf.placeholder(tf.int32, (None,), name='source_sequence_length')
    
    return input_data, targets, learning_rate, keep_probability, target_sequence_length, max_target_sequence_length, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    '''Remove the last word id from each batch and concat the <GO> to the begining of each batch'''
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)

    return dec_input 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    
    # Encoder embedding
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)

    # RNN cell
    def make_cell(rnn_size):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return enc_cell

    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    enc_output, enc_state = tf.nn.dynamic_rnn(enc_cell, enc_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return enc_output, enc_state
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    
    
    # 1. Decoder Embedding
    # dec_embed_input

    # 2. Construct the decoder cell
   
    #dec_cell
   
    # 3. Dense layer to translate the decoder's output at each time 
    # step into a choice from the target vocabulary
    #output_layer 


    # 4. Set up a training decoder and an inference decoder
    # Training Decoder
   

    # Helper for the training process. Used by BasicDecoder to read inputs.
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                            sequence_length=target_sequence_length,
                                                            time_major=False)
        
        
    # Basic decoder
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                           training_helper,
                                                           encoder_state,
                                                           output_layer) 
        
    # Perform dynamic decoding using the decoder
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                       impute_finished=True,
                                                                       maximum_iterations=max_summary_length)[0]
 
    
    
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    
    #with tf.variable_scope("decode", reuse=True):
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')

    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
        
    # Perform dynamic decoding using the decoder
    inference_decoder_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                            impute_finished=True,
                                                            maximum_iterations=max_target_sequence_length)[0]
         

    
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # 1. Decoder Embedding
   
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    # 2. Construct the decoder cell
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return dec_cell

    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
     
    # 3. Dense layer to translate the decoder's output at each time 
    # step into a choice from the target vocabulary
    output_layer = Dense(target_vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))


    # 4. Set up a training decoder and an inference decoder
    # Training Decoder
    with tf.variable_scope("decode"):
        training_decoder_output= decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob)
    with tf.variable_scope("decode", reuse=True):
        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'],
                         target_vocab_to_int['<EOS>'], max_target_sequence_length,
                         target_vocab_size, output_layer, batch_size, keep_prob)
    
    
    return training_decoder_output, inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # Pass the input data through the encoder. We'll ignore the encoder output, but use the state
    _, enc_state = encoding_layer(input_data, 
                                  rnn_size, 
                                  num_layers, 
                                  keep_prob,
                                  source_sequence_length,
                                  source_vocab_size, 
                                  enc_embedding_size)
   
    
    # Prepare the target sequences we'll feed to the decoder in training mode
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    # Pass encoder state and decoder inputs to the decoders
    training_decoder_output, inference_decoder_output = decoding_layer(dec_input,
                                                                       enc_state,
                                                                       target_sequence_length,
                                                                       max_target_sentence_length,
                                                                       rnn_size,
                                                                       num_layers, 
                                                                       target_vocab_to_int,
                                                                       target_vocab_size,
                                                                       batch_size,
                                                                       keep_prob, 
                                                                       dec_embedding_size) 
    
  
    
    return training_decoder_output, inference_decoder_output
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 8
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 64
decoding_embedding_size = 64
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = .8
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2101, Validation Accuracy: 0.3185, Loss: 4.4645
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.2703, Validation Accuracy: 0.3366, Loss: 3.5066
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3016, Validation Accuracy: 0.3672, Loss: 3.2308
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.3379, Validation Accuracy: 0.4038, Loss: 3.0419
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.3645, Validation Accuracy: 0.4297, Loss: 2.9648
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4133, Validation Accuracy: 0.4414, Loss: 2.7257
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.5647, Validation Accuracy: 0.5629, Loss: 0.8946
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.5136, Validation Accuracy: 0.5579, Loss: 0.9602
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.5148, Validation Accuracy: 0.5575, Loss: 0.9103
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.5383, Validation Accuracy: 0.5661, Loss: 0.8858
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.5130, Validation Accuracy: 0.5714, Loss: 0.8579
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.5133, Validation Accuracy: 0.5810, Loss: 0.8899
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.5504, Validation Accuracy: 0.5714, Loss: 0.8958
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.5913, Validation Accuracy: 0.5756, Loss: 0.7925
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.5454, Validation Accuracy: 0.5653, Loss: 0.8408
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.5551, Validation Accuracy: 0.5902, Loss: 0.8506
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5324, Validation Accuracy: 0.5824, Loss: 0.8198
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5820, Loss: 0.8256
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.5173, Validation Accuracy: 0.5586, Loss: 0.9323
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.5367, Validation Accuracy: 0.5700, Loss: 0.8332
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.5520, Validation Accuracy: 0.5817, Loss: 0.7980
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.5508, Validation Accuracy: 0.5923, Loss: 0.7992
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.5734, Validation Accuracy: 0.5916, Loss: 0.8087
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.5785, Validation Accuracy: 0.5877, Loss: 0.7602
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.5633, Validation Accuracy: 0.5938, Loss: 0.8023
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.5043, Validation Accuracy: 0.5810, Loss: 0.8267
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5831, Loss: 0.7806
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.5874, Validation Accuracy: 0.6094, Loss: 0.7269
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5927, Loss: 0.7862
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.5656, Validation Accuracy: 0.6126, Loss: 0.7480
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.5871, Validation Accuracy: 0.6080, Loss: 0.7230
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.5670, Validation Accuracy: 0.6051, Loss: 0.7756
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.5699, Validation Accuracy: 0.6040, Loss: 0.7243
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.6246, Validation Accuracy: 0.6349, Loss: 0.6006
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.6352, Validation Accuracy: 0.6275, Loss: 0.5854
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.6168, Validation Accuracy: 0.6413, Loss: 0.6060
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.6348, Validation Accuracy: 0.6420, Loss: 0.5827
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.6734, Validation Accuracy: 0.6392, Loss: 0.5457
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.6469, Validation Accuracy: 0.6452, Loss: 0.5789
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.6269, Validation Accuracy: 0.6367, Loss: 0.5359
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.6131, Validation Accuracy: 0.6335, Loss: 0.5739
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.6570, Validation Accuracy: 0.6417, Loss: 0.5306
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.6469, Validation Accuracy: 0.6548, Loss: 0.5425
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.5941, Validation Accuracy: 0.6548, Loss: 0.5647
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.6352, Validation Accuracy: 0.6438, Loss: 0.5373
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.6492, Validation Accuracy: 0.6445, Loss: 0.5295
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.6066, Validation Accuracy: 0.6570, Loss: 0.5511
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.6525, Validation Accuracy: 0.6413, Loss: 0.5191
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.6349, Validation Accuracy: 0.6577, Loss: 0.5400
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.6611, Validation Accuracy: 0.6531, Loss: 0.5155
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.6566, Validation Accuracy: 0.6406, Loss: 0.5044
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.6264, Validation Accuracy: 0.6587, Loss: 0.4846
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.6548, Validation Accuracy: 0.6381, Loss: 0.4815
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.6285, Validation Accuracy: 0.6364, Loss: 0.5311
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.6207, Validation Accuracy: 0.6491, Loss: 0.5250
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.6367, Validation Accuracy: 0.6499, Loss: 0.5268
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.6110, Validation Accuracy: 0.6385, Loss: 0.5038
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.6324, Validation Accuracy: 0.6353, Loss: 0.5074
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.6598, Validation Accuracy: 0.6577, Loss: 0.5035
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.6891, Validation Accuracy: 0.6499, Loss: 0.4871
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.8252, Validation Accuracy: 0.8164, Loss: 0.2454
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.8320, Validation Accuracy: 0.8253, Loss: 0.2383
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.8355, Validation Accuracy: 0.7876, Loss: 0.2528
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.8281, Validation Accuracy: 0.8125, Loss: 0.2293
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.8531, Validation Accuracy: 0.8072, Loss: 0.2090
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.8609, Validation Accuracy: 0.8363, Loss: 0.2381
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.8326, Validation Accuracy: 0.8058, Loss: 0.2002
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.8549, Validation Accuracy: 0.8228, Loss: 0.2154
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.8482, Validation Accuracy: 0.8075, Loss: 0.2148
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.8281, Validation Accuracy: 0.7997, Loss: 0.2064
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.8277, Validation Accuracy: 0.8249, Loss: 0.2182
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.8375, Validation Accuracy: 0.8232, Loss: 0.1958
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.8707, Validation Accuracy: 0.8288, Loss: 0.1961
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.8289, Validation Accuracy: 0.8224, Loss: 0.2143
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.8337, Validation Accuracy: 0.8189, Loss: 0.1999
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.8363, Validation Accuracy: 0.8182, Loss: 0.2026
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.8467, Validation Accuracy: 0.8416, Loss: 0.1997
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.8777, Validation Accuracy: 0.8359, Loss: 0.1847
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.8487, Validation Accuracy: 0.8398, Loss: 0.1765
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.8754, Validation Accuracy: 0.8221, Loss: 0.1718
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.8023, Validation Accuracy: 0.8498, Loss: 0.2073
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.8203, Validation Accuracy: 0.8129, Loss: 0.2002
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.8398, Validation Accuracy: 0.8562, Loss: 0.2047
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.8660, Validation Accuracy: 0.8263, Loss: 0.1848
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.8484, Validation Accuracy: 0.8235, Loss: 0.1788
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.8555, Validation Accuracy: 0.8480, Loss: 0.1927
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.8660, Validation Accuracy: 0.8420, Loss: 0.1838
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.9104, Validation Accuracy: 0.8395, Loss: 0.1709
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.8406, Validation Accuracy: 0.8366, Loss: 0.1883
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.8805, Validation Accuracy: 0.8462, Loss: 0.1647
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.8899, Validation Accuracy: 0.8416, Loss: 0.1655
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.8445, Validation Accuracy: 0.8480, Loss: 0.1629
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.8320, Validation Accuracy: 0.8391, Loss: 0.1739
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.8492, Validation Accuracy: 0.8441, Loss: 0.1777
# Epoch   2 Batch  410/1077 - Train Accuracy: 0.8507, Validation Accuracy: 0.8370, Loss: 0.1788
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.9008, Validation Accuracy: 0.8679, Loss: 0.1462
# Epoch   2 Batch  430/1077 - Train Accuracy: 0.8781, Validation Accuracy: 0.8587, Loss: 0.1481
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.8215, Validation Accuracy: 0.8303, Loss: 0.1683
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8430, Loss: 0.1601
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.8306, Loss: 0.1605
# Epoch   2 Batch  470/1077 - Train Accuracy: 0.8828, Validation Accuracy: 0.8370, Loss: 0.1545
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.8861, Validation Accuracy: 0.8647, Loss: 0.1562
# Epoch   2 Batch  490/1077 - Train Accuracy: 0.8445, Validation Accuracy: 0.8597, Loss: 0.1548
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.8512, Loss: 0.1374
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8395, Loss: 0.1468
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.8996, Validation Accuracy: 0.8491, Loss: 0.1306
# Epoch   2 Batch  530/1077 - Train Accuracy: 0.8551, Validation Accuracy: 0.8345, Loss: 0.1413
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8459, Loss: 0.1219
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.8371, Validation Accuracy: 0.8587, Loss: 0.1348
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.8762, Validation Accuracy: 0.8519, Loss: 0.1322
# Epoch   2 Batch  570/1077 - Train Accuracy: 0.8713, Validation Accuracy: 0.8377, Loss: 0.1418
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.8999, Validation Accuracy: 0.8629, Loss: 0.1191
# Epoch   2 Batch  590/1077 - Train Accuracy: 0.8392, Validation Accuracy: 0.8540, Loss: 0.1479
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.8583, Validation Accuracy: 0.8580, Loss: 0.1355
# Epoch   3 Batch  350/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.9031, Loss: 0.0737
# Epoch   3 Batch  360/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.8913, Loss: 0.0633
# Epoch   3 Batch  370/1077 - Train Accuracy: 0.9200, Validation Accuracy: 0.9020, Loss: 0.0692
# Epoch   3 Batch  380/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9059, Loss: 0.0674
# Epoch   3 Batch  390/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8952, Loss: 0.0741
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9112, Loss: 0.0776
# Epoch   3 Batch  410/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8938, Loss: 0.0811
# Epoch   3 Batch  420/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9141, Loss: 0.0552
# Epoch   3 Batch  430/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9190, Loss: 0.0631
# Epoch   3 Batch  440/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.9031, Loss: 0.0802
# Epoch   3 Batch  450/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.8974, Loss: 0.0689
# Epoch   3 Batch  460/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9031, Loss: 0.0705
# Epoch   3 Batch  470/1077 - Train Accuracy: 0.9276, Validation Accuracy: 0.9027, Loss: 0.0691
# Epoch   3 Batch  480/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.8945, Loss: 0.0658
# Epoch   3 Batch  490/1077 - Train Accuracy: 0.8883, Validation Accuracy: 0.8899, Loss: 0.0729
# Epoch   3 Batch  500/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9087, Loss: 0.0641
# Epoch   3 Batch  510/1077 - Train Accuracy: 0.8996, Validation Accuracy: 0.9059, Loss: 0.0672
# Epoch   3 Batch  520/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9059, Loss: 0.0577
# Epoch   3 Batch  530/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.9219, Loss: 0.0625
# Epoch   3 Batch  540/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.9073, Loss: 0.0537
# Epoch   3 Batch  550/1077 - Train Accuracy: 0.8961, Validation Accuracy: 0.8942, Loss: 0.0597
# Epoch   3 Batch  560/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.8924, Loss: 0.0576
# Epoch   3 Batch  570/1077 - Train Accuracy: 0.9120, Validation Accuracy: 0.8945, Loss: 0.0740
# Epoch   3 Batch  580/1077 - Train Accuracy: 0.9267, Validation Accuracy: 0.9062, Loss: 0.0508
# Epoch   3 Batch  590/1077 - Train Accuracy: 0.8882, Validation Accuracy: 0.8814, Loss: 0.0723
# Epoch   3 Batch  600/1077 - Train Accuracy: 0.9193, Validation Accuracy: 0.9194, Loss: 0.0656
# Epoch   4 Batch   80/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9116, Loss: 0.0430
# Epoch   4 Batch   90/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9237, Loss: 0.0509
# Epoch   4 Batch  100/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9339, Loss: 0.0454
# Epoch   4 Batch  110/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9300, Loss: 0.0392
# Epoch   4 Batch  120/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9499, Loss: 0.0522
# Epoch   4 Batch  130/1077 - Train Accuracy: 0.9356, Validation Accuracy: 0.9112, Loss: 0.0415
# Epoch   4 Batch  140/1077 - Train Accuracy: 0.9494, Validation Accuracy: 0.9208, Loss: 0.0414
# Epoch   4 Batch  150/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.9283, Loss: 0.0545
# Epoch   4 Batch  160/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9201, Loss: 0.0399
# Epoch   4 Batch  170/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9329, Loss: 0.0482
# Epoch   4 Batch  180/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9361, Loss: 0.0409
# Epoch   4 Batch  190/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9155, Loss: 0.0369
# Epoch   4 Batch  200/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9261, Loss: 0.0458
# Epoch   4 Batch  210/1077 - Train Accuracy: 0.9438, Validation Accuracy: 0.9332, Loss: 0.0461
# Epoch   4 Batch  220/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9411, Loss: 0.0454
# Epoch   4 Batch  230/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9364, Loss: 0.0440
# Epoch   4 Batch  240/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9219, Loss: 0.0416
# Epoch   4 Batch  250/1077 - Train Accuracy: 0.9325, Validation Accuracy: 0.9435, Loss: 0.0443
# Epoch   4 Batch  260/1077 - Train Accuracy: 0.9360, Validation Accuracy: 0.9545, Loss: 0.0369
# Epoch   4 Batch  270/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.9336, Loss: 0.0523
# Epoch   4 Batch  280/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.9322, Loss: 0.0491
# Epoch   4 Batch  290/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9414, Loss: 0.0609
# Epoch   4 Batch  300/1077 - Train Accuracy: 0.9704, Validation Accuracy: 0.9492, Loss: 0.0359
# Epoch   4 Batch  310/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9364, Loss: 0.0444
# Epoch   4 Batch  320/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9283, Loss: 0.0526
# Epoch   4 Batch  330/1077 - Train Accuracy: 0.9207, Validation Accuracy: 0.9510, Loss: 0.0483
# Epoch   4 Batch  340/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9265, Loss: 0.0399
# Epoch   4 Batch  350/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9212, Loss: 0.0406
# Epoch   4 Batch  360/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9453, Loss: 0.0337
# Epoch   4 Batch  370/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9300, Loss: 0.0408
# Epoch   4 Batch  380/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9592, Loss: 0.0407
# Epoch   4 Batch  390/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9492, Loss: 0.0473
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9627, Loss: 0.0496
# Epoch   4 Batch  410/1077 - Train Accuracy: 0.9046, Validation Accuracy: 0.9464, Loss: 0.0564
# Epoch   4 Batch  420/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9620, Loss: 0.0305
# Epoch   4 Batch  430/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9361, Loss: 0.0405
# Epoch   4 Batch  440/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9432, Loss: 0.0526
# Epoch   4 Batch  450/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9418, Loss: 0.0439
# Epoch   4 Batch  460/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9411, Loss: 0.0456
# Epoch   4 Batch  470/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9315, Loss: 0.0396
# Epoch   4 Batch  480/1077 - Train Accuracy: 0.9474, Validation Accuracy: 0.9389, Loss: 0.0411
# Epoch   4 Batch  490/1077 - Train Accuracy: 0.9043, Validation Accuracy: 0.9180, Loss: 0.0467
# Epoch   4 Batch  500/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9393, Loss: 0.0352
# Epoch   4 Batch  510/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9442, Loss: 0.0439
# Epoch   4 Batch  520/1077 - Train Accuracy: 0.9728, Validation Accuracy: 0.9371, Loss: 0.0340
# Epoch   4 Batch  530/1077 - Train Accuracy: 0.9223, Validation Accuracy: 0.9347, Loss: 0.0417
# Epoch   4 Batch  540/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9496, Loss: 0.0322
# Epoch   4 Batch  550/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9329, Loss: 0.0363
# Epoch   4 Batch  560/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9414, Loss: 0.0354
# Epoch   4 Batch  570/1077 - Train Accuracy: 0.9190, Validation Accuracy: 0.9180, Loss: 0.0516
# Epoch   4 Batch  580/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.9467, Loss: 0.0332
# Epoch   4 Batch  590/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9528, Loss: 0.0430
# Epoch   4 Batch  600/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9535, Loss: 0.0413
# Epoch   4 Batch  610/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9482, Loss: 0.0433
# Epoch   4 Batch  620/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9545, Loss: 0.0341
# Epoch   4 Batch  630/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9648, Loss: 0.0387
# Epoch   4 Batch  640/1077 - Train Accuracy: 0.9405, Validation Accuracy: 0.9510, Loss: 0.0384
# Epoch   4 Batch  650/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9496, Loss: 0.0413
# Epoch   4 Batch  660/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9332, Loss: 0.0344
# Epoch   4 Batch  670/1077 - Train Accuracy: 0.9606, Validation Accuracy: 0.9425, Loss: 0.0435
# Epoch   4 Batch  680/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.9492, Loss: 0.0463
# Epoch   4 Batch  690/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9499, Loss: 0.0404
# Epoch   4 Batch  700/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9446, Loss: 0.0304
# Epoch   4 Batch  710/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9407, Loss: 0.0319
# Epoch   4 Batch  720/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9645, Loss: 0.0396
# Epoch   4 Batch  730/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9489, Loss: 0.0423
# Epoch   4 Batch  740/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9524, Loss: 0.0315
# Epoch   4 Batch  750/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9553, Loss: 0.0348
# Epoch   4 Batch  760/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9624, Loss: 0.0442
# Epoch   4 Batch  770/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.9432, Loss: 0.0423
# Epoch   4 Batch  780/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9421, Loss: 0.0517
# Epoch   4 Batch  790/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9411, Loss: 0.0436
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9790, Loss: 0.0356
# Epoch   4 Batch  810/1077 - Train Accuracy: 0.9513, Validation Accuracy: 0.9567, Loss: 0.0313
# Epoch   4 Batch  820/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9577, Loss: 0.0387
# ...
# Epoch   6 Batch  460/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9478, Loss: 0.0229
# Epoch   6 Batch  470/1077 - Train Accuracy: 0.9630, Validation Accuracy: 0.9581, Loss: 0.0231
# Epoch   6 Batch  480/1077 - Train Accuracy: 0.9794, Validation Accuracy: 0.9510, Loss: 0.0226
# Epoch   6 Batch  490/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9489, Loss: 0.0238
# Epoch   6 Batch  500/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9677, Loss: 0.0188
# Epoch   6 Batch  510/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9727, Loss: 0.0254
# Epoch   6 Batch  520/1077 - Train Accuracy: 0.9799, Validation Accuracy: 0.9638, Loss: 0.0182
# Epoch   6 Batch  530/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9613, Loss: 0.0262
# Epoch   6 Batch  540/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9528, Loss: 0.0185
# Epoch   6 Batch  550/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9492, Loss: 0.0228
# Epoch   6 Batch  560/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9453, Loss: 0.0241
# Epoch   6 Batch  570/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9606, Loss: 0.0323
# Epoch   6 Batch  580/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9517, Loss: 0.0206
# Epoch   6 Batch  590/1077 - Train Accuracy: 0.9642, Validation Accuracy: 0.9723, Loss: 0.0238
# Epoch   6 Batch  600/1077 - Train Accuracy: 0.9740, Validation Accuracy: 0.9652, Loss: 0.0225
# Epoch   6 Batch  610/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9670, Loss: 0.0219
# Epoch   6 Batch  620/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9620, Loss: 0.0207
# Epoch   6 Batch  630/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9545, Loss: 0.0222
# Epoch   6 Batch  640/1077 - Train Accuracy: 0.9650, Validation Accuracy: 0.9688, Loss: 0.0201
# Epoch   6 Batch  650/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9606, Loss: 0.0239
# Epoch   6 Batch  660/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9553, Loss: 0.0193
# Epoch   6 Batch  670/1077 - Train Accuracy: 0.9776, Validation Accuracy: 0.9638, Loss: 0.0204
# Epoch   6 Batch  680/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9524, Loss: 0.0284
# Epoch   6 Batch  690/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9513, Loss: 0.0223
# Epoch   6 Batch  700/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9592, Loss: 0.0165
# Epoch   6 Batch  710/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9531, Loss: 0.0158
# Epoch   6 Batch  720/1077 - Train Accuracy: 0.9433, Validation Accuracy: 0.9656, Loss: 0.0228
# Epoch   6 Batch  730/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9670, Loss: 0.0286
# Epoch   6 Batch  740/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9648, Loss: 0.0188
# Epoch   6 Batch  750/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9425, Loss: 0.0202
# Epoch   6 Batch  760/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9698, Loss: 0.0212
# Epoch   6 Batch  770/1077 - Train Accuracy: 0.9483, Validation Accuracy: 0.9631, Loss: 0.0253
# Epoch   6 Batch  780/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9467, Loss: 0.0332
# Epoch   6 Batch  790/1077 - Train Accuracy: 0.9543, Validation Accuracy: 0.9723, Loss: 0.0280
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9677, Loss: 0.0233
# Epoch   6 Batch  810/1077 - Train Accuracy: 0.9725, Validation Accuracy: 0.9695, Loss: 0.0165
# Epoch   6 Batch  820/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9652, Loss: 0.0202
# Epoch   6 Batch  830/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9606, Loss: 0.0252
# Epoch   6 Batch  840/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9634, Loss: 0.0203
# Epoch   6 Batch  850/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9648, Loss: 0.0380
# Epoch   6 Batch  860/1077 - Train Accuracy: 0.9583, Validation Accuracy: 0.9510, Loss: 0.0213
# Epoch   6 Batch  870/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9609, Loss: 0.0229
# Epoch   6 Batch  880/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9606, Loss: 0.0295
# Epoch   6 Batch  890/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9567, Loss: 0.0248
# Epoch   6 Batch  900/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9659, Loss: 0.0227
# Epoch   6 Batch  910/1077 - Train Accuracy: 0.9669, Validation Accuracy: 0.9659, Loss: 0.0201
# Epoch   6 Batch  920/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9684, Loss: 0.0179
# Epoch   6 Batch  930/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9684, Loss: 0.0156
# Epoch   6 Batch  940/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9588, Loss: 0.0184
# Epoch   6 Batch  950/1077 - Train Accuracy: 0.9628, Validation Accuracy: 0.9638, Loss: 0.0172
# Epoch   6 Batch  960/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9560, Loss: 0.0208
# Epoch   6 Batch  970/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9634, Loss: 0.0209
# Epoch   6 Batch  980/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9702, Loss: 0.0261
# Epoch   6 Batch  990/1077 - Train Accuracy: 0.9671, Validation Accuracy: 0.9666, Loss: 0.0247
# Epoch   6 Batch 1000/1077 - Train Accuracy: 0.9658, Validation Accuracy: 0.9652, Loss: 0.0206
# Epoch   6 Batch 1010/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9496, Loss: 0.0165
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9659, Loss: 0.0167
# Epoch   6 Batch 1030/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9691, Loss: 0.0187
# Epoch   6 Batch 1040/1077 - Train Accuracy: 0.9634, Validation Accuracy: 0.9411, Loss: 0.0192
# Epoch   7 Batch  520/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9638, Loss: 0.0143
# Epoch   7 Batch  530/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9659, Loss: 0.0197
# Epoch   7 Batch  540/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9510, Loss: 0.0138
# Epoch   7 Batch  550/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9489, Loss: 0.0174
# Epoch   7 Batch  560/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9570, Loss: 0.0204
# Epoch   7 Batch  570/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9581, Loss: 0.0266
# Epoch   7 Batch  580/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9588, Loss: 0.0187
# Epoch   7 Batch  590/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9744, Loss: 0.0193
# Epoch   7 Batch  600/1077 - Train Accuracy: 0.9654, Validation Accuracy: 0.9627, Loss: 0.0197
# Epoch   7 Batch  610/1077 - Train Accuracy: 0.9597, Validation Accuracy: 0.9652, Loss: 0.0170
# Epoch   7 Batch  620/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9673, Loss: 0.0186
# Epoch   7 Batch  630/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9663, Loss: 0.0173
# Epoch   7 Batch  640/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9723, Loss: 0.0160
# Epoch   7 Batch  650/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9602, Loss: 0.0180
# Epoch   7 Batch  660/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9709, Loss: 0.0128
# Epoch   7 Batch  670/1077 - Train Accuracy: 0.9755, Validation Accuracy: 0.9609, Loss: 0.0149
# Epoch   7 Batch  680/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9450, Loss: 0.0210
# Epoch   7 Batch  690/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9592, Loss: 0.0188
# Epoch   7 Batch  700/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9677, Loss: 0.0127
# Epoch   7 Batch  710/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9567, Loss: 0.0118
# Epoch   7 Batch  720/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9556, Loss: 0.0193
# Epoch   7 Batch  730/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9680, Loss: 0.0259
# Epoch   7 Batch  740/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9570, Loss: 0.0131
# Epoch   7 Batch  750/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9545, Loss: 0.0167
# Epoch   7 Batch  760/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9691, Loss: 0.0167
# Epoch   7 Batch  770/1077 - Train Accuracy: 0.9643, Validation Accuracy: 0.9673, Loss: 0.0194
# Epoch   7 Batch  780/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9592, Loss: 0.0283
# Epoch   7 Batch  790/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9734, Loss: 0.0236
# Epoch   7 Batch  800/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9773, Loss: 0.0167
# Epoch   7 Batch  810/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9673, Loss: 0.0132
# Epoch   7 Batch  820/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9627, Loss: 0.0164
# Epoch   7 Batch  830/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9634, Loss: 0.0229
# Epoch   7 Batch  840/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9730, Loss: 0.0195
# Epoch   7 Batch  850/1077 - Train Accuracy: 0.9714, Validation Accuracy: 0.9663, Loss: 0.0327
# Epoch   7 Batch  860/1077 - Train Accuracy: 0.9736, Validation Accuracy: 0.9648, Loss: 0.0159
# Epoch   7 Batch  870/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9723, Loss: 0.0179
# Epoch   7 Batch  880/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9531, Loss: 0.0237
# Epoch   7 Batch  890/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9613, Loss: 0.0171
# Epoch   7 Batch  900/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9666, Loss: 0.0238
# Epoch   7 Batch  910/1077 - Train Accuracy: 0.9736, Validation Accuracy: 0.9648, Loss: 0.0182
# Epoch   7 Batch  920/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9659, Loss: 0.0143
# Epoch   7 Batch  930/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9670, Loss: 0.0133
# Epoch   7 Batch  940/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9545, Loss: 0.0143
# Epoch   7 Batch  950/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9663, Loss: 0.0132
# Epoch   7 Batch  960/1077 - Train Accuracy: 0.9736, Validation Accuracy: 0.9553, Loss: 0.0192
# Epoch   7 Batch  970/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9663, Loss: 0.0179
# Epoch   7 Batch  980/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9723, Loss: 0.0224
# Epoch   7 Batch  990/1077 - Train Accuracy: 0.9729, Validation Accuracy: 0.9663, Loss: 0.0196
# Epoch   7 Batch 1000/1077 - Train Accuracy: 0.9632, Validation Accuracy: 0.9673, Loss: 0.0172
# Epoch   7 Batch 1010/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9652, Loss: 0.0147
# Epoch   7 Batch 1020/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9641, Loss: 0.0142
# Epoch   7 Batch 1030/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9716, Loss: 0.0162
# Epoch   7 Batch 1040/1077 - Train Accuracy: 0.9618, Validation Accuracy: 0.9585, Loss: 0.0174
# Epoch   7 Batch 1050/1077 - Train Accuracy: 0.9867, Validation Accuracy: 0.9560, Loss: 0.0117
# Epoch   7 Batch 1060/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9719, Loss: 0.0130
# Epoch   7 Batch 1070/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9659, Loss: 0.0129
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    sentence = sentence.lower()
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.split()]
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [26, 83, 13, 119, 7, 30, 74]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [164, 280, 62, 41, 335, 292, 212, 290, 1]
#   French Words: il n'aimait pas un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
